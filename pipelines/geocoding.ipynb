# %% [markdown]
# 1. Geocoding: Address -> Latitude, Longitude
#    1. company_profile: Add latitude & longitude, update json files.
#    2. json_data: Update json files profile section with latitude and longitude.

# %%
# Open JSON for each file
import json
import os

# Install Geocoding Library
import sys
# !{sys.executable} -m pip install geopy
# Out:
# Requirement already satisfied: geopy in /Users/rod608/opt/anaconda3/lib/python3.9/site-packages (2.3.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /Users/rod608/opt/anaconda3/lib/python3.9/site-packages (from geopy) (2.0)

# %% [markdown]
# Companies with no data attached to them.

# %%
directory_for_company_profile = '../data/raw/company_profile'
invalid_files = []
valid_files = []

for filename in os.listdir(directory_for_company_profile):
    with open(os.path.join(directory_for_company_profile, filename)) as f:
        data = json.load(f)

        # Invalid Files: No data/address found.
        if type(data) == str:
            print(f"NO DATA FOUND FOR: {filename}. Message: {data}")
            invalid_files.append(filename)
            continue
        
        elif "address1" not in data:
            print(f"NO ADDRESS FOUND FOR: {filename}. Message: {data}")
            invalid_files.append(filename)
            continue
        
        # Valid Files!
        valid_files.append(filename)

print(f"\n{len(invalid_files)} invalid files: {invalid_files}")
print(f"\n{len(valid_files)} valid files: {valid_files}")
# Out:
# NO DATA FOUND FOR: AIMAU.json. Message: No fundamentals data found for any of the summaryTypes=assetProfile
# NO DATA FOUND FOR: BRK.B.json. Message: No fundamentals data found for any of the summaryTypes=assetProfile
# NO DATA FOUND FOR: AGM.A.json. Message: Quote not found for ticker symbol: AGM.A
# NO DATA FOUND FOR: ALCY.json. Message: No fundamentals data found for any of the summaryTypes=assetProfile
# NO DATA FOUND FOR: CRD.A.json. Message: Quote not found for ticker symbol: CRD.A
# NO DATA FOUND FOR: CRD.B.json. Message: No fundamentals data found for any of the summaryTypes=assetProfile
# NO DATA FOUND FOR: AACT.json. Message: No fundamentals data found for any of the summaryTypes=assetProfile
# NO DATA FOUND FOR: GODN.json. Message: Quote not found for ticker symbol: GODN
# NO ADDRESS FOUND FOR: WHF.json. Message: {'city': 'Miami', 'state': 'FL', 'country': 'United States', 'website': 'https://www.whitehorsefinance.com', 'industry': 'Asset Management', 'industryDisp': 'Asset Management', 'sector': 'Financial Services', 'longBusinessSummary': 'WhiteHorse Finance, Inc. is business development company, non-diversified, closed end management company specializing in originating senior secured loans, lower middle market, growth capital industries. It prefers to invest in United States. It typically invests between $5 million to $25 million in companies having enterprise value of between $50 million and $350 million.', 'companyOfficers': [{'maxAge': 1, 'name': 'Mr. Stuart D. Aronson', 'age': 59, 'title': 'CEO & Director', 'yearBorn': 1963, 'fiscalYear': 2022, 'totalPay': 0, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Joyson C. Thomas CPA', 'age': 40, 'title': 'CFO & Principal Accounting Officer', 'yearBorn': 1982, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Brian  Schaffer', 'title': 'Investor Relations Contact', 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Marco A. Collazos', 'age': 46, 'title': 'Chief Compliance Officer', 'yearBorn': 1976, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Richard H. Siegel J.D.', 'age': 56, 'title': 'Sec.', 'yearBorn': 1966, 'exercisedValue': 0, 'unexercisedValue': 0}], 'compensationAsOfEpochDate': '2022-12-30 19:00:00', 'maxAge': 86400}
# NO DATA FOUND FOR: CATC.json. Message: No fundamentals data found for any of the summaryTypes=assetProfile
# NO DATA FOUND FOR: MSAC.json. Message: Quote not found for ticker symbol: MSAC
# NO DATA FOUND FOR: BMO.json. Message: No fundamentals data found for any of the summaryTypes=assetProfile
# NO DATA FOUND FOR: OAKU.json. Message: Quote not found for ticker symbol: OAKU
#
# 13 invalid files: ['AIMAU.json', 'BRK.B.json', 'AGM.A.json', 'ALCY.json', 'CRD.A.json', 'CRD.B.json', 'AACT.json', 'GODN.json', 'WHF.json', 'CATC.json', 'MSAC.json', 'BMO.json', 'OAKU.json']
#
# 1165 valid files: ['BLFY.json', 'CPAA.json', 'PJT.json', 'AXS.json', 'STC.json', 'LCW.json', 'AIHS.json', 'PKBK.json', 'PUCK.json', 'SEDA.json', 'COOL.json', 'ACAQ.json', 'SPFI.json', 'FANH.json', 'LDI.json', 'MTRY.json', 'SCU.json', 'BOCN.json', 'ANZU.json', 'TBMC.json', 'SAL.json', 'BCSF.json', 'BNS.json', 'GPAC.json', 'LX.json', 'TLGY.json', 'ISRL.json', 'AFAR.json', 'WULF.json', 'IVCA.json', 'CPUH.json', 'PRK.json', 'GAMC.json', 'IFS.json', 'FMIV.json', 'TENK.json', 'BMAC.json', 'RNST.json', 'IGTA.json', 'ENVA.json', 'BSRR.json', 'ORI.json', 'HALL.json', 'GBCI.json', 'UVSP.json', 'BSIG.json', 'ADER.json', 'ORCC.json', 'OBT.json', 'BEN.json', 'ONB.json', 'SYF.json', 'AACI.json', 'GLAD.json', 'BHRB.json', 'ARES.json', 'PTHR.json', 'WRLD.json', 'RACY.json', 'AGAC.json', 'CHAA.json', 'RBB.json', 'DMYY.json', 'SMBK.json', 'PNTM.json', 'ROSE.json', 'GBNY.json', 'EBMT.json', 'EFHT.json', 'GBRG.json', 'CADE.json', 'OZK.json', 'MEGL.json', 'AVAL.json', 'PSPC.json', 'HDB.json', 'SUPV.json', 'UPTD.json', 'XPDB.json', 'GAIN.json', 'LPLA.json', 'DECA.json', 'UFCS.json', 'NBST.json', 'WTBA.json', 'ASPA.json', 'BFH.json', 'PFBC.json', 'USCB.json', 'AMP.json', 'CVII.json', 'FSNB.json', 'SGII.json', 'MCAG.json', 'CSTR.json', 'YRD.json', 'GSD.json', 'IMAQ.json', 'HMST.json', 'TCFC.json', 'USB.json', 'NTRS.json', 'FACT.json', 'UNAM.json', 'NICK.json', 'PLAO.json', 'AEG.json', 'WT.json', 'HTBK.json', 'CSLM.json', 'UVE.json', 'BTWN.json', 'HGTY.json', 'BPRN.json', 'APMI.json', 'MBAC.json', 'BANF.json', 'EMCG.json', 'SNTG.json', 'DGICA.json', 'BTBT.json', 'RF.json', 'GSQB.json', 'BBUC.json', 'BN.json', 'WAFD.json', 'AMBC.json', 'HIG.json', 'BGCP.json', 'AMRK.json', 'JWAC.json', 'FINV.json', 'GHIX.json', 'LSBK.json', 'TMKR.json', 'PNFP.json', 'CLOE.json', 'HCI.json', 'WSBC.json', 'UBSI.json', 'KNSW.json', 'SLQT.json', 'BAC.json', 'ACAH.json', 'ASB.json', 'INBK.json', 'BRLI.json', 'VCXB.json', 'FRXB.json', 'AVHI.json', 'SCM.json', 'FCFS.json', 'BTCS.json', 'BCBP.json', 'CNO.json', 'L.json', 'LIVB.json', 'AFL.json', 'TIPT.json', 'MBCN.json', 'MGLD.json', 'BANR.json', 'FINW.json', 'ICCH.json', 'RAND.json', 'FDUS.json', 'ASCB.json', 'OPRT.json', 'CZNC.json', 'MDWT.json', 'TLGA.json', 'ITIC.json', 'BIOS.json', 'NRAC.json', 'SKGR.json', 'QCRH.json', 'SAGA.json', 'SMFG.json', 'MLAC.json', 'CME.json', 'WU.json', 'BFIN.json', 'HFBL.json', 'BITF.json', 'FLFV.json', 'MTAC.json', 'PWOD.json', 'LU.json', 'MSVB.json', 'GDNR.json', 'BCML.json', 'MCAF.json', 'BRBS.json', 'LGVC.json', 'BMA.json', 'RWAY.json', 'MS.json', 'THG.json', 'GDOT.json', 'CRBG.json', 'EQH.json', 'BHF.json', 'CBOE.json', 'LVAC.json', 'DB.json', 'ARTE.json', 'ESQ.json', 'CFFS.json', 'NOVV.json', 'TIRX.json', 'NPAB.json', 'NWG.json', 'CACC.json', 'TCBC.json', 'NSTD.json', 'PFLT.json', 'BOAC.json', 'ROCL.json', 'PEBK.json', 'LMFA.json', 'UNB.json', 'PNAC.json', 'PFIS.json', 'GLBZ.json', 'OVBC.json', 'LAZ.json', 'BSAQ.json', 'CUBI.json', 'JT.json', 'HAFC.json', 'CBU.json', 'LRFC.json', 'SHBI.json', 'MAQC.json', 'GLST.json', 'HUT.json', 'LCNB.json', 'FBMS.json', 'CHEA.json', 'RRAC.json', 'NU.json', 'ATMV.json', 'CFBK.json', 'WWAC.json', 'SDAC.json', 'IROQ.json', 'SNFCA.json', 'BUR.json', 'AUB.json', 'BRDG.json', 'BKU.json', 'CFIV.json', 'AUBN.json', 'GBDC.json', 'STEP.json', 'HLNE.json', 'GHI.json', 'HYW.json', 'KEY.json', 'RDN.json', 'DNAB.json', 'TBBK.json', 'RONI.json', 'RJAC.json', 'NISN.json', 'MGYR.json', 'NWLI.json', 'CNDA.json', 'OCAX.json', 'BLK.json', 'BBD.json', 'IVZ.json', 'ATMC.json', 'RFAC.json', 'IBOC.json', 'CATY.json', 'RRBI.json', 'BWAC.json', 'RBCAA.json', 'NODK.json', 'OVLY.json', 'BBAR.json', 'XP.json', 'PFC.json', 'BNRE.json', 'EQBK.json', 'UTAA.json', 'SLVR.json', 'NRIM.json', 'ADOC.json', 'BPOP.json', 'AMAO.json', 'FFBC.json', 'BKCC.json', 'GENQ.json', 'EGGF.json', 'CETU.json', 'TWOA.json', 'IOAC.json', 'NWFL.json', 'PEGR.json', 'DUNE.json', 'FNCB.json', 'CLAY.json', 'BYTS.json', 'GGAL.json', 'MCAA.json', 'AB.json', 'BAP.json', 'PRA.json', 'CWBC.json', 'JXN.json', 'MCY.j ...

# %% [markdown]
# Get the valid addresses for each company.

# %%
company_address = {}

for filename in valid_files:
    with open(os.path.join(directory_for_company_profile, filename)) as f:
        data = json.load(f)

        # Street Address
        address = ""
        address += data["address1"] + " " if "address1" in data else ''
        # address += data["address2"] + " " if "address2" in data else ''
        address += data["city"] + " " if "city" in data else ''
        address += data["state"] + " " if "state" in data else ''
        address += data["zip"] + " " if "zip" in data else ''
        address += data["country"] if "country" in data else ''

        # Add to dictionary
        company_address[filename] = address

print(company_address)
print(len(company_address))
# Out:
# {'BLFY.json': '19 Park Avenue Rutherford NJ 07070 United States', 'CPAA.json': '999 Vanderbilt Beach Road Naples FL 34108 United States', 'PJT.json': '280 Park Avenue New York NY 10017 United States', 'AXS.json': '92 Pitts Bay Road Pembroke HM 08 Bermuda', 'STC.json': '1360 Post Oak Boulevard Houston TX 77056 United States', 'LCW.json': '11755 Wilshire Boulevard Los Angeles CA 90025 United States', 'AIHS.json': 'Shihao Square Chengdu 610000 China', 'PKBK.json': '601 Delsea Drive Washington Township NJ 08080 United States', 'PUCK.json': '12600 Hill Country Blvd Building R Bee Cave TX 78738 United States', 'SEDA.json': 'One Grand Central Place New York NY 10165 United States', 'COOL.json': '251 Lytton Avenue Palo Alto CA 94301 United States', 'ACAQ.json': '442 5th Avenue New York NY 10018 United States', 'SPFI.json': '5219 City Bank Parkway Lubbock TX 79407 United States', 'FANH.json': 'Pearl River Tower Guangzhou 510623 China', 'LDI.json': '26642 Towne Centre Drive Foothill Ranch CA 92610 United States', 'MTRY.json': '17 State Street New York NY 10004 United States', 'SCU.json': '9 West 57th Street New York NY 10019 United States', 'BOCN.json': '2 Wisconsin Circle Chevy Chase MD 20815 United States', 'ANZU.json': '12610 Race Track Road Tampa FL 33626 United States', 'TBMC.json': '510 Madison Avenue New York NY 10022 United States', 'SAL.json': '5 Bissell Street Lakeville CT 06039 United States', 'BCSF.json': '200 Clarendon Street Boston MA 02116 United States', 'BNS.json': '40 Temperance Street Toronto ON M5H 0B4 Canada', 'GPAC.json': '200 Park Avenue New York NY 10166 United States', 'LX.json': 'CES Tower Shenzhen 518057 China', 'TLGY.json': '4001 Kennett Pike Wilmington DE 19807 United States', 'ISRL.json': 'Building R Bee Cave TX 78738 United States', 'AFAR.json': 'Royal One Phillip Singapore 048692 Singapore', 'WULF.json': '9 Federal Street Easton MD 21601 United States', 'IVCA.json': 'Century Yard George Town KY1-1102 Cayman Islands', 'CPUH.json': '1100 North Market Street Wilmington DE 19890 United States', 'PRK.json': '50 North Third Street Newark OH 43058-3500 United States', 'GAMC.json': '10 East 53rd Street New York NY 10022 United States', 'IFS.json': 'Torre Interbank Lima 13 Peru', 'FMIV.json': '1615 South Congress Avenue Delray Beach FL 33445 United States', 'TENK.json': '420 Lexington Avenue New York NY 10170 United States', 'BMAC.json': '425 Houston Street Fort Worth TX 76102 United States', 'RNST.json': '209 Troy Street Tupelo MS 38804-4827 United States', 'IGTA.json': '875 Washington Street New York NY 10014 United States', 'ENVA.json': '175 West Jackson Boulevard Chicago IL 60604 United States', 'BSRR.json': '86 North Main Street Porterville CA 93257 United States', 'ORI.json': '307 North Michigan Avenue Chicago IL 60601 United States', 'HALL.json': 'Two Lincoln Centre Dallas TX 75240-2345 United States', 'GBCI.json': '49 Commons Loop Kalispell MT 59901 United States', 'UVSP.json': '14 North Main Street Souderton PA 18964 United States', 'BSIG.json': '200 Clarendon Street Boston MA 02116 United States', 'ADER.json': 'OfficeEdge Miami Miami FL 33131 United States', 'ORCC.json': '399 Park Avenue New York NY 10022 United States', 'OBT.json': '212 Dolson Avenue Middletown NY 10940 United States', 'BEN.json': 'One Franklin Parkway San Mateo CA 94403 United States', 'ONB.json': 'One Main Street Evansville IN 47708 United States', 'SYF.json': '777 Long Ridge Road Stamford CT 06902 United States', 'AACI.json': '1760 Market Street Philadelphia PA 19103 United States', 'GLAD.json': '1521 Westbranch Drive McLean VA 22102 United States', 'BHRB.json': '100 S. Fairfax Street Alexandria VA 22314 United States', 'ARES.json': '2000 Avenue of the Stars Los Angeles CA 90067 United States', 'PTHR.json': '643 Ilalo Street Honolulu HI 96813 United States', 'WRLD.json': '104 S. Main Street Greenville SC 29601 United States', 'RACY.json': '3753 Howard Hughes Parkway Las Vegas NV 89169 United States', 'AGAC.json': '322 West 52nd Stree ...
# 1165

# %%
# Import Geocoding Library
from geopy.geocoders import ArcGIS

# Geocoding Example: JPMorgan Chase
geolocator = ArcGIS()

print(company_address["JPM.json"])
location = geolocator.geocode(company_address["JPM.json"])
print((location.latitude, location.longitude))
# Out:
# 383 Madison Avenue New York NY 10179 United States
# (40.75584606302709, -73.97688227425184)

# %%
# import sleep to prevent timeout
from time import sleep

company_latitude_longitude: dict[str, (float, float)] = {}
invalid_locations = []

# Geocoding for all companies
for company in company_address:
    location = geolocator.geocode(company_address[company])

    # If location is not found, skip
    if location is None:
        print(f"NO LOCATION FOUND FOR: {company}")
        invalid_locations.append(company)
        continue

    company_latitude_longitude[company] = (location.latitude, location.longitude)
    # sleep(1)

print(f"\nUnable to geocode {len(invalid_locations)} locations: {invalid_locations} ")
print(f"\nAble to geocode {len(company_latitude_longitude)} locations: {company_latitude_longitude} ")
# Out:
# Unable to geocode 0 locations: []
#
# Able to geocode 1165 locations: {'BLFY.json': (40.8279269937556, -74.10199600928556), 'CPAA.json': (26.2511849898152, -81.7993230008517), 'PJT.json': (40.75636607630008, -73.97494714426573), 'AXS.json': (32.29133692926005, -64.79248377453608), 'STC.json': (29.75279960346621, -95.45996336574034), 'LCW.json': (34.048902999632475, -118.46214903446946), 'AIHS.json': (30.666670000000067, 104.06667000000004), 'PKBK.json': (39.74567300628203, -75.11392197344169), 'PUCK.json': (30.308152986833903, -97.93749898576061), 'SEDA.json': (40.75217432172232, -73.97754312227553), 'COOL.json': (37.44658200882682, -122.1633870071561), 'ACAQ.json': (40.751795173041415, -73.98234861622674), 'SPFI.json': (33.560836009476716, -101.92591697067297), 'FANH.json': (23.116670000000056, 113.25000000000011), 'LDI.json': (33.675146016141, -117.66625103432045), 'MTRY.json': (40.70289137805946, -74.0141535801879), 'SCU.json': (40.76379822602672, -73.97518343011625), 'BOCN.json': (38.96160199724213, -77.0854930379826), 'ANZU.json': (28.067043008314002, -82.63739898923663), 'TBMC.json': (40.759562012161865, -73.97454053814269), 'SAL.json': (41.96752099411913, -73.4394489756969), 'BCSF.json': (42.34922733267268, -71.07513118119684), 'BNS.json': (43.650951396511374, -79.38028629840365), 'GPAC.json': (40.75397362967672, -73.97640190738086), 'LX.json': (22.545540000000074, 114.06830000000002), 'TLGY.json': (39.779226980069296, -75.5971609873684), 'ISRL.json': (30.30645249049254, -97.97939787557631), 'AFAR.json': (1.284981379883817, 103.8500148634659), 'WULF.json': (38.775291928201746, -76.07649174626681), 'IVCA.json': (19.29281590900007, -81.36769499999997), 'CPUH.json': (39.746732017838724, -75.54643203296997), 'PRK.json': (40.05942901599195, -82.40291901976006), 'GAMC.json': (40.759995021279906, -73.97521461079606), 'IFS.json': (-12.051489999999944, -77.02491999999995), 'FMIV.json': (26.437809991854152, -80.0916200317869), 'TENK.json': (40.75232819631626, -73.97549317483073), 'BMAC.json': (32.75455501058816, -97.3319450380895), 'RNST.json': (34.256237002208934, -88.70503296549667), 'IGTA.json': (40.74133866501103, -74.00702058058559), 'ENVA.json': (41.8777560078901, -87.63320103643146), 'BSRR.json': (36.06666099096958, -119.01594003616643), 'ORI.json': (41.88708598813372, -87.62420297955359), 'HALL.json': (32.92423000000008, -96.81669999999997), 'GBCI.json': (48.21999492040834, -114.32842723761146), 'UVSP.json': (40.30947598177448, -75.32175302287645), 'BSIG.json': (42.34922733267268, -71.07513118119684), 'ADER.json': (25.76685100000003, -80.18872999999996), 'ORCC.json': (40.75932358892604, -73.9720873227213), 'OBT.json': (41.426167940453695, -74.42922685035934), 'BEN.json': (37.54327791426384, -122.2919796579156), 'ONB.json': (37.969333052436504, -87.57532951423694), 'SYF.json': (41.0967379813533, -73.56197102626878), 'AACI.json': (39.95307262790864, -75.16970448098701), 'GLAD.json': (38.92716905517838, -77.22076077816112), 'BHRB.json': (38.80427099243005, -77.04229899544376), 'ARES.json': (34.058355984305194, -118.41433899403286), 'PTHR.json': (21.297051017776624, -157.86491502908288), 'WRLD.json': (34.84941699767924, -82.40030101612224), 'RACY.json': (36.121173826673584, -115.1580146066403), 'AGAC.json': (40.76393573114831, -73.98637343849352), 'CHAA.json': (1.295244685046029, 103.85956738323887), 'RBB.json': (34.05253999123934, -118.26269402087792), 'DMYY.json': (36.18210498531447, -115.31046702308136), 'SMBK.json': (35.937171986297315, -83.9923639800364), 'PNTM.json': (30.141898985086897, -95.47018402976458), 'ROSE.json': (33.88570198038859, -84.4229959903392), 'GBNY.json': (42.90839075711946, -76.79324800930603), 'EBMT.json': (46.59163969875854, -112.01599040628224), 'EFHT.json': (42.25207700964626, -70.92302595773853), 'GBRG.json': (22.279775143731285, 114.17824021269485), 'CADE.json': (34.25630598527208, -88.70382898892454), 'OZK.json': (34.81035640687233, -92.47039325184673), 'MEGL.json': (22.2810118516353, 114.15660274874261), 'AVAL.json': (4.6147800072 ...

# %%
# Add Latitude & Longitude to Company Profile JSONs
directory_for_company_profile = '../data/raw/company_profile'

for filename in valid_files:
    with open(os.path.join(directory_for_company_profile, filename)) as f:
        data = json.load(f)

        # Add Latitude & Longitude
        data["latitude"] = company_latitude_longitude[filename][0]
        data["longitude"] = company_latitude_longitude[filename][1]

        # Save to JSON
        with open(os.path.join(directory_for_company_profile, filename), 'w') as outfile:
            json.dump(data, outfile)

# %%
# Add Latitude & Longitude to the profile section of the general JSON Data
directory_for_json_data = '../data/raw/json_data'

for filename in valid_files:
    with open(os.path.join(directory_for_json_data, filename)) as f:
        data = json.load(f)

        # Add Latitude & Longitude
        data["profile"]["latitude"] = company_latitude_longitude[filename][0]
        data["profile"]["longitude"] = company_latitude_longitude[filename][1]

        # Save to JSON
        with open(os.path.join(directory_for_json_data, filename), 'w') as outfile:
            json.dump(data, outfile)
